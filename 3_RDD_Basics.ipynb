# %%
from pyspark import SparkContext

# %%
sc = SparkContext(master="local",appName="Example_3")

# %%
inputWords =["spark","hadoop","spark","Hive","pig","hadoop","cassandra"]


wordRDD= sc.parallelize(inputWords)

# %%
print("count:{}".format(wordRDD.count()))
# Out:
# count:7

# %%
wordcountByValue =wordRDD.countByValue()

type(wordcountByValue)
# Out:
# collections.defaultdict

# %%
wordcountByValue
# Out:
# defaultdict(int,
#             {'spark': 2, 'hadoop': 2, 'Hive': 1, 'pig': 1, 'cassandra': 1})

# %%
wordCountByKeys = wordRDD.countByKey()

# %%
wordCountByKeys
# Out:
# defaultdict(int, {'s': 2, 'h': 2, 'H': 1, 'p': 1, 'c': 1})
